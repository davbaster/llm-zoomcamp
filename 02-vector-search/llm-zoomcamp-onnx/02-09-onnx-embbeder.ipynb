# %% [markdown]
# #### Same pipeline, no PyTorch
#
# Let's repeat the examples from earlier and confirm the numbers match.
#
# First, comparing two queries against a document:

# %%
from embedder import Embedder

embed = Embedder()

q1 = "Can I still join the course after the start date?"
q2 = "How to install Docker on Windows?"
d  = "You don't need to register. You're accepted. You can also just start learning and submitting homework without registering."

v1 = embed.encode(q1)
v2 = embed.encode(q2)
dv = embed.encode(d)

# %% [markdown]
# Compute similarities:

# %%
v1.dot(dv)
# Out:
# np.float64(0.3233238425677314)

# %% [markdown]
# And the second similarity:

# %%
v2.dot(dv)
# Out:
# np.float64(0.01973045838992233)

# %% [markdown]
# We get the same result as before. The first score is higher because the query about joining the course is more similar to the document about registration.
#
# Next, we embed the FAQ dataset.
#
# If you didn't fetch *ingest.py* earlier, grab it now:
#
# wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/ingest.py

# %% [markdown]
# Load the documents:

# %%
from ingest import load_faq_data

documents = load_faq_data()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ingest import load_faq_data
#       2
#       3 documents = load_faq_data()
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\ingest.py:2
#       1 import requests
# ----> 2 from minsearch import Index
#       5 def load_faq_data():
#       6     docs_url = 'https://datatalks.club/faq/json/courses.json'
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\minsearch\__init__.py:1
# ----> 1 from minsearch.minsearch import Index
#       2 from minsearch.append import AppendableIndex
#       3 from minsearch.vector import VectorSearch
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\minsearch\minsearch.py:4
#       1 import pickle
#       2 from pathlib import Path
# ----> 4 import pandas as pd
#       6 from sklearn.feature_extraction.text import TfidfVectorizer
#       7 from sklearn.metrics.pairwise import cosine_similarity
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\pandas\errors\__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File C:\DATA\Cursos\llm-zoomcamp\02-vector-search\llm-zoomcamp-onnx\.venv\Lib\site-packages\pandas\_libs\tslibs\__init__.py:41
#       1 __all__ = [
#       2     "BaseOffset",
#       3     "Day",
#    (...)     37     "tz_convert_from_utc_single",
#      38 ]
#      40 from pandas._libs.tslibs import dtypes
# ---> 41 from pandas._libs.tslibs.conversion import localize_pydatetime
#      42 from pandas._libs.tslibs.dtypes import (
#      43     Resolution,
#      44     periods_per_day,
#      45     periods_per_second,
#      46 )
#      47 from pandas._libs.tslibs.nattype import (
#      48     NaT,
#      49     NaTType,
#      50     iNaT,
#      51     nat_strings,
#      52 )
#
# File pandas/_libs/tslibs/conversion.pyx:1, in init pandas._libs.tslibs.conversion()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# ImportError: DLL load failed while importing offsets: Una directiva de Control de aplicaciones bloqueó este archivo.

# %% [markdown]
# Combine question and answer for each document:
