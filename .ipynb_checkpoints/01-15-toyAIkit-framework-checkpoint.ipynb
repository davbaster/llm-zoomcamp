# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
openai_client = OpenAI()

# %% [markdown]
# uv add toyaikit

# %%
from toyaikit.llm import OpenAIClient
from toyaikit.tools import Tools
from toyaikit.chat import IPythonChatInterface
from toyaikit.chat.runners import OpenAIResponsesRunner, DisplayingRunnerCallback

# %%
instructions = """
You're a course teaching assistant.
You're given a question from a course student and your task is to answer it.

If you want to look up information, use the search function. 
Use as many keywords from the user question as possible when making first requests.

Make multiple searches.

Try to expand your search by using new keywords
based on the results you get from the search.

At the end, ask if there are other areas that the user wants to explore.
""".strip()

# %% [markdown]
# ### Defining the tool
# First we define a top-level search function that queries the index directly. The model will reference it by this name. We keep the Python function and the tool name aligned so the dispatch is easier later.

# %%
def search(query):
    boost_dict = {"question": 3.0, "section": 0.5}
    filter_dict = {"course": "llm-zoomcamp"}

    return index.search(
        query,
        num_results=5,
        boost_dict=boost_dict,
        filter_dict=filter_dict
    )

# %% [markdown]
# Next we tell the model about this function. The model doesn't see our Python code, only a schema describing what the function does and what arguments it takes. LLMs are language agnostic. At the end we're just making an HTTP call, so we describe the tool in JSON rather than in Python. The same schema would work from TypeScript or Java.

# %%
search_tool = {
    "type": "function",
    "name": "search",
    "description": "Search the FAQ database for entries matching the given query.",
    "parameters": {
        "type": "object",
        "properties": {
            "query": {
                "type": "string",
                "description": "Search query text to look up in the course FAQ."
            }
        },
        "required": ["query"],
        "additionalProperties": False
    }
}

# %% [markdown]
# The description is the most important field, because the model reads it to decide when to call the function. parameters is a JSON schema for the arguments, and we mark query as required so the model always fills it in.

# %% [markdown]
# ### Registering the tool

# %%
agent_tools = Tools()
agent_tools.add_tool(search, search_tool)

# %% [markdown]
# ### Letting ToyAIKit generate the schema
# Writing that schema by hand is annoying, and we don't want to do it for every function. So we don't have to.
#
# If we add a type hint and a docstring to search, ToyAIKit reads them and derives the schema for us:

# %%
def search(query: str) -> dict[str, str]:
    """
    Search the FAQ database for entries matching the given query.
    """
    return index.search(
        query,
        num_results=5,
        boost_dict={"question": 3.0, "section": 0.5},
        filter_dict={"course": "llm-zoomcamp"}
    )

# %% [markdown]
# Then register it without passing a schema:

# %%
agent_tools = Tools()
agent_tools.add_tool(search)

# %% [markdown]
# You can look at what ToyAIKit produced.

# %%
agent_tools.get_tools()
# Out:
# [{'type': 'function',
#   'name': 'search',
#   'description': 'Search the FAQ database for entries matching the given query.',
#   'parameters': {'type': 'object',
#    'properties': {'query': {'type': 'string',
#      'description': 'query parameter'}},
#    'required': ['query'],
#    'additionalProperties': False}}]

# %% [markdown]
# ### The chat interface and runner
# Create the chat interface and a callback, then build the runner:

# %%
chat_interface = IPythonChatInterface()
callback = DisplayingRunnerCallback(chat_interface)

runner = OpenAIResponsesRunner(
    tools=agent_tools,
    developer_prompt=instructions,
    chat_interface=chat_interface,
    llm_client=OpenAIClient(model="gpt-5.4-nano")
)

# %% [markdown]
# The chat_interface handles display in the notebook. The callback renders model messages and tool calls as they happen. The runner runs the agent loop, the same while True we wrote by hand. It sends messages, executes function calls, adds tool outputs back, and repeats until the model is done.
#
# We pick gpt-5.4-mini here on purpose. Without it, ToyAIKit falls back to a smaller, faster default that doesn't follow the instructions as reliably.

# %% [markdown]
# ### Running one prompt

# %%
result = runner.loop(
    prompt="How do I run Olama locally?",
    callback=callback,
)
# Out:
# -> Response received
#             <details>
#             <summary>Function call: <tt>search({"query":"Ollama run locally install"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"Ollama run locally install"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"Ollama local run command pull model r...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"Ollama local run command pull model run"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"Olama localhost API"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"Olama localhost API"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"Ollama system requirements Docker Win...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"Ollama system requirements Docker Windows macOS Linux"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>Here’s how to run <strong>Ollama locally</strong> (on your own computer). I’ll outline the common steps for <strong>Windows/macOS/Linux</strong> and include the exact commands.</p>
# <h2>1) Install Ollama</h2>
# <p>Download/install Ollama from the official site: <strong>https://ollama.com</strong></p>
# <p>After install, verify it works by running:</p>
# <pre><code class="language-bash">ollama --version
# </code></pre>
# <h2>2) Pull a model (download it locally)</h2>
# <p>Example:</p>
# <pre><code class="language-bash">ollama pull llama3
# </code></pre>
# <p>(You can pick other models; the usual pattern is <code>ollama pull &lt;model-name&gt;</code>.)</p>
# <h2>3) Run the model (start an interactive chat)</h2>
# <pre><code class="language-bash">ollama run llama3
# </code></pre>
# <p>You should get a prompt where you can start chatting.</p>
# <h2>4) Run a model with a one-off prompt (optional)</h2>
# <pre><code class="language-bash">ollama run llama3 &quot;Explain what a neural network is.&quot;
# </code></pre>
# <h2>5) (Optional) Use the Ollama Web UI / REST API</h2>
# <p>Ollama commonly exposes:</p>
# <ul>
# <li>a local web interface (if included in your install/settings)</li>
# <li>a REST API for programmatic use (usually at <code>http://localhost:11434</code>)</li>
# </ul>
# <p>If you tell me your OS and whether you want <strong>CLI only</strong> or <strong>API usage</strong>, I can provide the exact curl/examples.</p>
# <hr />
# <h3>Quick checklist</h3>
# <ul>
# <li>Install Ollama</li>
# <li><code>ollama pull &lt;model&gt;</code></li>
# <li><code>ollama run &lt;model&gt;</code></li>
# </ul>
# <hr />
# <p>What OS are you using (<strong>Windows, macOS, or Linux</strong>)—and do you want to run it via <strong>terminal only</strong> or also use the <strong>API</strong>?</p>
# </div>
#             </div>

# %% [markdown]
# We used the typo "Olama" on purpose. The agent searches and gets poor results, then retries with "Ollama". The recovery is the same as the handwritten loop. The notebook output is nicer to watch. Each tool call and message renders inline, so you can look at every search result.
#
# The result is a LoopResult with all_messages (the full conversation), token counts, and cost (computed from token usage).

# %% [markdown]
# ### Cost and tokens

# %%
result.cost
# Out:
# CostInfo(input_cost=Decimal('0.0001022'), output_cost=Decimal('0.00055'), total_cost=Decimal('0.0006522'))

# %% [markdown]
# You can also look at the full message history.

# %%
result.all_messages
# Out:
# [EasyInputMessage(content="You're a course teaching assistant.\nYou're given a question from a course student and your task is to answer it.\n\nIf you want to look up information, use the search function. \nUse as many keywords from the user question as possible when making first requests.\n\nMake multiple searches.\n\nTry to expand your search by using new keywords\nbased on the results you get from the search.\n\nAt the end, ask if there are other areas that the user wants to explore.", role='developer', phase=None, type=None),
#  EasyInputMessage(content='How do I run Olama locally?', role='user', phase=None, type=None),
#  ResponseFunctionToolCall(arguments='{"query":"Ollama run locally install"}', call_id='call_Bk7eeOiEBv2hoqwRsP49VzcJ', name='search', type='function_call', id='fc_088c514e85172958006a34be8ce9248192bb923b9e1813df7d', namespace=None, status='completed'),
#  ResponseFunctionToolCall(arguments='{"query":"Ollama local run command pull model run"}', call_id='call_WIkqL5RQin2TaCd7CK9Jrivm', name='search', type='function_call', id='fc_088c514e85172958006a34be8ce9348192b9e426b865433c9d', namespace=None, status='completed'),
#  ResponseFunctionToolCall(arguments='{"query":"Olama localhost API"}', call_id='call_9ogZbNbdvxBPQmwDcwSjTlto', name='search', type='function_call', id='fc_088c514e85172958006a34be8ce938819288c9b5450c74a347', namespace=None, status='completed'),
#  ResponseFunctionToolCall(arguments='{"query":"Ollama system requirements Docker Windows macOS Linux"}', call_id='call_KA9ruDpaoaEC3XCjrsYNqnPZ', name='search', type='function_call', id='fc_088c514e85172958006a34be8ce9408192b835927d21c31fed', namespace=None, status='completed'),
#  {'type': 'function_call_output',
#   'call_id': 'call_Bk7eeOiEBv2hoqwRsP49VzcJ',
#   'output': '{\n  "error": "NameError: name \'index\' is not defined"\n}'},
#  {'type': 'function_call_output',
#   'call_id': 'call_WIkqL5RQin2TaCd7CK9Jrivm',
#   'output': '{\n  "error": "NameError: name \'index\' is not defined"\n}'},
#  {'type': 'function_call_output',
#   'call_id': 'call_9ogZbNbdvxBPQmwDcwSjTlto',
#   'output': '{\n  "error": "NameError: name \'index\' is not defined"\n}'},
#  {'type': 'function_call_output',
#   'call_id': 'call_KA9ruDpaoaEC3XCjrsYNqnPZ',
#   'output': '{\n  "error": "NameError: name \'index\' is not defined"\n}'},
#  ResponseOutputMessage(id='msg_088c514e85172958006a34be8fd0348192b09c0051b995bae3', content=[ResponseOutputText(annotations=[], text='Here’s how to run **Ollama locally** (on your own computer). I’ll outline the common steps for **Windows/macOS/Linux** and include the exact commands.\n\n## 1) Install Ollama\nDownload/install Ollama from the official site: **https://ollama.com**\n\nAfter install, verify it works by running:\n```bash\nollama --version\n```\n\n## 2) Pull a model (download it locally)\nExample:\n```bash\nollama pull llama3\n```\n\n(You can pick other models; the usual pattern is `ollama pull <model-name>`.)\n\n## 3) Run the model (start an interactive chat)\n```bash\nollama run llama3\n```\n\nYou should get a prompt where you can start chatting.\n\n## 4) Run a model with a one-off prompt (optional)\n```bash\nollama run llama3 "Explain what a neural network is."\n```\n\n## 5) (Optional) Use the Ollama Web UI / REST API\nOllama commonly exposes:\n- a local web interface (if included in your install/settings)\n- a REST API for programmatic use (usually at `http://localhost:11434`)\n\nIf you tell me your OS and whether you want **CLI only** or **API usage**, I can provide the exact curl/examples.\n\n---\n\n### Quick checklist\n- Install Ollama\n- `ollama pull <model>`\n- `ollama run <model>`\n\n---\n\nWhat OS are you using (**Windows, macOS, or Linux**)—and do you want to run it via **terminal only** or also use the **API**?', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase='final_answer')]

# %% [markdown]
# This is just a list - the same messages list we maintained by hand.

# %% [markdown]
# ### Continuing the conversation
# Take the messages from the previous result and pass them as previous_messages on the next loop call:

# %%
result2 = runner.loop(
    prompt="How do I run a different model?",
    previous_messages=result.all_messages,
    callback=callback,
)
# Out:
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>To run a different model in Ollama, you just <strong>pull the model</strong> you want and then <strong>run it by name</strong>.</p>
# <h3>1) Pull the model</h3>
# <p>Example (replace <code>MODEL_NAME</code> with the model you want):</p>
# <pre><code class="language-bash">ollama pull MODEL_NAME
# </code></pre>
# <p>Common examples you might see:</p>
# <pre><code class="language-bash">ollama pull llama3
# ollama pull mistral
# ollama pull qwen2
# </code></pre>
# <h3>2) Run that model</h3>
# <pre><code class="language-bash">ollama run MODEL_NAME
# </code></pre>
# <h3>3) If you’re not sure what model names to use</h3>
# <p>List what you already have downloaded:</p>
# <pre><code class="language-bash">ollama list
# </code></pre>
# <p>If you want, tell me the model name you’re aiming for (or what you want it to do—coding, faster, smaller, etc.), and I’ll suggest a good one and the exact commands. Are you on Windows, macOS, or Linux?</p>
# </div>
#             </div>

# %% [markdown]
# The runner picks up where the last call left off, with the same agent loop and an extended history. The model knows "different model" refers to Ollama because it sees the previous turn in memory. Without that history, it would have no idea what we're asking about.

# %% [markdown]
# ### Interactive chat
# For a chat-like workflow, run the built-in input loop:

# %%
runner.run()
# Out:
# You: how long does this course takes?
# -> Response received
#             <details>
#             <summary>Function call: <tt>search({"query":"course how long does this course take...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"course how long does this course take duration weeks months"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"course length timeline schedule total...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"course length timeline schedule total hours"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"how long does it take to complete the...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"how long does it take to complete the course"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"course duration FAQ"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"course duration FAQ"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>I can help—however I need one detail first: <strong>which specific course (name/code) are you referring to?</strong><br />
# Course lengths vary depending on the exact course.</p>
# <p>If you tell me the <strong>course title or code</strong>, I’ll reply with the expected <strong>duration (e.g., weeks/months) and typical weekly time commitment</strong>.</p>
# <p>Which course are you enrolled in? Any other areas you want to explore (e.g., pacing, start/end dates, or workload)?</p>
# </div>
#             </div>
# You: llm
# -> Response received
#             <details>
#             <summary>Function call: <tt>search({"query":"LLM course how long does it take dura...)</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"LLM course how long does it take duration"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"\"LLM\" course length weeks"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"\"LLM\" course length weeks"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"LLM program timeline total hours"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"LLM program timeline total hours"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
#             <details>
#             <summary>Function call: <tt>search({"query":"LLM FAQ completion time"})</tt></summary>
#             <div>
#                 <b>Call</b>
#                 <pre>{"query":"LLM FAQ completion time"}</pre>
#             </div>
#             <div>
#                 <b>Output</b>
#                 <pre>{
#   "error": "NameError: name 'index' is not defined"
# }</pre>
#             </div>
#
#             </details>
# -> Response received
#             <div>
#                 <div><b>Assistant:</b></div>
#                 <div><p>Thanks—when you say <strong>“LLM”</strong>, do you mean:</p>
# <ol>
# <li>a <strong>course titled “LLM”</strong> (about Large Language Models), or</li>
# <li>an <strong>“LLM” degree</strong> (Master of Laws)?</li>
# </ol>
# <p>Also, if it’s the course: <strong>what platform/school</strong> is it on (or do you have a link/syllabus)?<br />
# Once I have that, I can tell you the exact <strong>duration (weeks/months)</strong> and the <strong>typical time per week</strong>.</p>
# <p>Which one is it—course or degree? And where is it from?</p>
# </div>
#             </div>
